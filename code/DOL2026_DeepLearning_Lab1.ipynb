# %% [markdown]
# # 🚀 Artificial Intelligence Lab 2026 | Deep Learning (MNIST)
# *From Pixels to Intelligence: Build Your Own Neural Networks* 🤖✨
#
# ---
#
# ### 🧠 Lab Topic
# **Handwritten Digit Classification (MNIST)**
# Design and compare **your own deep learning architectures**
#
# ---
#
# ### 🔬 What You’ll Learn
# - How Neural Networks work (from simple → deep)
# - How architecture affects performance
# - Training & evaluation in PyTorch
# - Model comparison & analysis
#
# ---
#
# ### 👨‍🏫 Instructor
# **Teerapong Panboonyuen (Kao)**
# AI Researcher | Chulalongkorn University
#
# ---
#
# ### 🎯 Lab Goal
# Build **3 models**:
# 1. Small model 🟢
# 2. Medium model 🟡
# 3. Deep model 🔴
#
# 👉 Then compare: **Which one is best? Why?**
#
# ---
#
# ### 🌏 Vision
# > “Great AI is not just trained — it is designed.”
#
# ---

# %%
# 🔧 Install (if needed)
# !pip install torch torchvision matplotlib

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %%
# 📦 Load MNIST dataset

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, download=True, transform=transform)

test_dataset = torchvision.datasets.MNIST(
    root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=64)

# %%
# 🔍 Visualize some digits

def show_samples():
    images, labels = next(iter(train_loader))
    fig, axes = plt.subplots(1, 8, figsize=(12, 3))

    for i in range(8):
        axes[i].imshow(images[i].squeeze(), cmap='gray')
        axes[i].set_title(f"Label: {labels[i].item()}")
        axes[i].axis('off')

    plt.show()

# Print your sample dataset

# %% [markdown]
# # 🧠 YOUR MISSION
#
# You will create **3 architectures**:
#
# ---
#
# ### 🟢 Model 1: Small Network
# - Few layers
# - Fast but less powerful
#
# ---
#
# ### 🟡 Model 2: Medium Network
# - More layers
# - Better representation
#
# ---
#
# ### 🔴 Model 3: Deep Network
# - Deep architecture
# - Higher performance (but slower)
#
# ---
#
# ### 🎯 Your Goal
# Compare:
# - Accuracy
# - Training speed
# - Overfitting
#
# 👉 Which architecture is BEST?

# %% [markdown]
# ---
#
# ### 🟢 Model 1: Small Network (Baseline)
#
# **Architecture:**
# - Input (28 × 28 image)
# - Flatten → (784)
# - Linear (784 → 128)
# - ReLU
# - Linear (128 → 10)
#
# **Idea:**
# - Simple and fast
# - Learns basic patterns (edges, shapes)
# - May underfit complex patterns
#
# ---

# %%
# 🟢 SMALL MODEL (Baseline)

# =========================
# TODO: Student Exercise
# =========================
# Complete the missing implementation below
# This part is intentionally left for experimentation

# %% [markdown]
# ---
#
# ### 🟡 Model 2: Medium Network
#
# **Architecture:**
# - Input (28 × 28 image)
# - Flatten → (784)
# - Linear (784 → 256)
# - ReLU
# - Linear (256 → 128)
# - ReLU
# - Linear (128 → 10)
#
# **Idea:**
# - Deeper representation
# - Learns more complex features
# - Better balance between speed and performance
#
# ---

# %%
# 🟡 MEDIUM MODEL

# =========================
# TODO: Student Exercise
# =========================
# Complete the missing implementation below
# This part is intentionally left for experimentation

# %% [markdown]
# ---
#
# ### 🔴 Model 3: Deep Network
#
# **Architecture:**
# - Input (28 × 28 image)
# - Flatten → (784)
# - Linear (784 → 512)
# - ReLU
# - Linear (512 → 256)
# - ReLU
# - Linear (256 → 128)
# - ReLU
# - Linear (128 → 64)
# - ReLU
# - Linear (64 → 10)
#
# **Idea:**
# - Deep feature extraction
# - Captures complex patterns
# - Higher accuracy potential
# - Risk of overfitting + slower training
#
# ---
#
# ### 🧠 Key Insight
#
# | Model | Depth | Speed | Accuracy | Risk |
# |------|------|------|---------|------|
# | Small | Low | ⚡ Fast | Low–Medium | Underfitting |
# | Medium | Medium | ⚖️ Balanced | Medium–High | Stable |
# | Deep | High | 🐢 Slower | High | Overfitting |
#
# ---
#
# ### 💡 Think Like an AI Engineer
#
# > More layers ≠ always better
# > The best model is the one that **fits the data just right**
#
# ---

# %%
# 🔴 DEEP MODEL (More layers)

# =========================
# TODO: Student Exercise
# =========================
# Complete the missing implementation below
# This part is intentionally left for experimentation

# %%
# 🔁 Training function

def train_model(model, name, epochs=3):
    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for images, labels in tqdm(train_loader, desc=f"{name} Epoch {epoch+1}"):
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        print(f"{name} Epoch {epoch+1} Loss: {total_loss:.4f}")

    return model

# %%
# 📊 Evaluation function

def evaluate(model):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    return correct / total

# %%
results = {}

models = {
    "SmallNet": SmallNet(),
    "MediumNet": MediumNet(),
    "DeepNet": DeepNet()
}

for name, model in models.items():
    trained = train_model(model, name)
    acc = evaluate(trained)
    results[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")

# %%
# 📈 Compare results

names = list(results.keys())
scores = list(results.values())

plt.bar(names, scores)
plt.title("Model Comparison")
plt.ylabel("Accuracy")
plt.show()

# %%
# 🔮 Show predictions

model = models["DeepNet"]  # best model (you can change)

images, labels = next(iter(test_loader))

with torch.no_grad():
    outputs = model(images.to(device))
    preds = torch.argmax(outputs, dim=1).cpu()

fig, axes = plt.subplots(1, 6, figsize=(12,3))

for i in range(6):
    axes[i].imshow(images[i].squeeze(), cmap='gray')
    axes[i].set_title(f"P:{preds[i]} / T:{labels[i]}")
    axes[i].axis('off')

plt.show()

# %% [markdown]
# # 🧠 Final Assignment
#
# ### 🎯 Your Task:
#
# 1. Modify ONE architecture (make it better)
# 2. Try:
#    - More layers
#    - Dropout
#    - Different activation
# 3. Train and compare results
#
# ---
#
# ### 🏆 Bonus:
# - Achieve **>98% accuracy**
# - Visualize mistakes
# - Try CNN instead of MLP
#
# ---
#
# ### 💡 Key Question:
# > Does deeper always mean better?
#
# ---
#
# ### 📌 Submission:
# - Colab notebook
# - Screenshot of results
# - Short explanation (3–5 sentences)
#
# ---
#
# ### 🔥 Final Thought:
# > “The best model is not the biggest —
# > it is the one designed with understanding.”
